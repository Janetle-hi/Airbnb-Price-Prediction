# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
#summary column
with open('output.csv',encoding='utf-8', mode = 'r') as f:
    lines = f.readlines() 
text = ''.join(lines)
f.close()

stopwords = STOPWORDS.copy()

wc = WordCloud(background_color='white',max_words=100, width=2000, height=1600, stopwords=stopwords, margin=10,random_state=1).generate(text)
plt.imshow(wc)
wc.to_file('wordcloud_figure.png')
plt.figure(figsize=(20,10))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# house rules
with open('output2.csv',encoding='utf-8', mode = 'r') as f:
    lines = f.readlines() 
text = ''.join(lines)
f.close()

stopwords = ('Please keep','Please','please','this','is','the','that','If','will','are','in','apartment','do')

wc = WordCloud(background_color='white',max_words=100, width=2000, height=1600, stopwords=stopwords, margin=10,random_state=1).generate(text)
plt.imshow(wc)
wc.to_file('wordcloud_figure.png')
plt.figure(figsize=(20,10))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# hourse rules with pic
with open('output2.csv',encoding='utf-8', mode = 'r') as f:
    lines = f.readlines() 
text = ''.join(lines)
f.close()

stopwords = ('Please keep','Please','please','this','is','the','that','If','will','are','in','apartment','do')

mask = np.array(Image.open(path.join('yellow-house-hi.png')))

wc = WordCloud(background_color="white", max_words=100, mask=mask,
               max_font_size=90, random_state=42)

wc.generate(text)

image_colors = ImageColorGenerator(mask)
plt.figure(figsize=(50,30))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
_=plt.show()

# %%
# amt
with open('output3.csv',encoding='utf-8', mode = 'r') as f:
    lines = f.readlines() 
text = ''.join(lines)
f.close()

stopwords = STOPWORDS.copy()

wc = WordCloud(background_color='white',max_words=100, width=2000, height=1600, stopwords=stopwords, margin=10,random_state=1).generate(text)
plt.imshow(wc)
wc.to_file('wordcloud_figure.png')
plt.figure(figsize=(20,10))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# descriptions
with open('output4.csv',encoding='utf-8', mode = 'r') as f:
    lines = f.readlines() 
text = ''.join(lines)
f.close()

stopwords = STOPWORDS.copy()

wc = WordCloud(background_color='white',max_words=100, width=2000, height=1600, stopwords=stopwords, margin=10,random_state=1).generate(text)
plt.imshow(wc)
wc.to_file('wordcloud_figure.png')
plt.figure(figsize=(20,10))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
